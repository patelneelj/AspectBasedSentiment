# %%
import pandas as pd

a=pd.read_csv("C:\\IS 698\\Project\\Reviews.csv")
#b = a.sentence, a.annotation

serv=a[['sentence','annotation']]
serv
# Out:
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.    Service
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...    Service
# 3     This place is a health hazard with the back ha...    Service
# 4     Amd mike the guy on the register giving food a...    Service
# 5                 Don't get me wrong, I love Taco Bell.      Other
# 6                          This Taco Bell, not so much.      Other
# 7     It's hard to go anywhere when the people that ...      Other
# 8      Have some pride in what you do even if it's n...      Other
# 9     I will drive quickly past this Taco Bell to ge...      Other
# 10        I'm a definite fan of this Taco Bell, in fact      Other
# 11    I secretly drive past one Taco Bell to go to t...      Other
# 12    I don't know if it is the newness of the build...   Location
# ...

# %%
food=a[['sentence','annotation']]

# %%
price=a[['sentence','annotation']]

# %%
other=a[['sentence','annotation']]

# %%
abm=a[['sentence','annotation']]

# %%
loc=a[['sentence','annotation']]

# %%
park=a[['sentence','annotation']]

# %%
serv.annotation.unique()
# Out:
# array(['Service', 'Food', 'Other', 'Location', 'Ambience', 'Price', 'WiFi',
#        nan, 'Parking_availability', 'other'], dtype=object)

# %%
#price.annotation.unique()
# Out:
# array(['Service', 'Food', 'Other', 'Location', 'Ambience', 'Price', 'WiFi',
#        nan, 'Parking_availability', 'other'], dtype=object)

# %%
import re
#serv['annotation']=serv['annotation'].str.replace(r'\s?S[\w]+','Service')

# %%
#food['annotation']=food['annotation'].str.replace(r'\s?S[\w]+','Food')

# %%
#other['annotation']=other['annotation'].str.replace(r'\s?S[\w]+','Other')

# %%
#price['annotation']=price['annotation'].str.replace(r'\s?S[\w]+','Price')

# %%
#abm['annotation']=abm['annotation'].str.replace(r'\s?S[\w]+','Ambience')

# %%
#loc['annotation']=loc['annotation'].str.replace(r'\s?S[\w]+','Location')

# %%
#park['annotation']=park['annotation'].str.replace(r'\s?S[\w]+','Parking_availability')

# %%
serv.annotation.unique()
park.annotation.unique()
abm.annotation.unique()
loc.annotation.unique()
price.annotation.unique()
food.annotation.unique()
other.annotation.unique()
# Out:
# array(['Service', 'Food', 'Other', 'Location', 'Ambience', 'Price', 'WiFi',
#        nan, 'Parking_availability', 'other'], dtype=object)

# %%
#test
food
# Out:
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.    Service
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...    Service
# 3     This place is a health hazard with the back ha...    Service
# 4     Amd mike the guy on the register giving food a...    Service
# 5                 Don't get me wrong, I love Taco Bell.      Other
# 6                          This Taco Bell, not so much.      Other
# 7     It's hard to go anywhere when the people that ...      Other
# 8      Have some pride in what you do even if it's n...      Other
# 9     I will drive quickly past this Taco Bell to ge...      Other
# 10        I'm a definite fan of this Taco Bell, in fact      Other
# 11    I secretly drive past one Taco Bell to go to t...      Other
# 12    I don't know if it is the newness of the build...   Location
# ...

# %%
serv.annotation[serv.annotation!='Service']='Not_Service'
serv
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence   annotation
# 0       Gross how can anyone serve food from a pig pen.      Service
# 1      I would not feed my dogs from this nasty so c...  Not_Service
# 2     With employees acting like it was high school ...      Service
# ...

# %%
food.annotation[food.annotation!='Food']='Not_Food'
food
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.   Not_Food
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...   Not_Food
# ...

# %%
loc.annotation[loc.annotation!='Location']='Not_Location'
loc
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence    annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Location
# 1      I would not feed my dogs from this nasty so c...  Not_Location
# 2     With employees acting like it was high school ...  Not_Location
# ...

# %%
price.annotation[price.annotation!='Price']='Not_Price'
price
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Price
# 1      I would not feed my dogs from this nasty so c...  Not_Price
# 2     With employees acting like it was high school ...  Not_Price
# ...

# %%
other.annotation[other.annotation!='Other']='Not_Other'
other
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Other
# 1      I would not feed my dogs from this nasty so c...  Not_Other
# 2     With employees acting like it was high school ...  Not_Other
# ...

# %%
abm.annotation[abm.annotation!='Ambience']='Not_Ambience'
abm
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence    annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Ambience
# 1      I would not feed my dogs from this nasty so c...  Not_Ambience
# 2     With employees acting like it was high school ...  Not_Ambience
# ...

# %%
park.annotation[park.annotation!='Parking_availability']='Not_Parking_availability'
park
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Rency\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                sentence  \
# 0       Gross how can anyone serve food from a pig pen.
# 1      I would not feed my dogs from this nasty so c...
# 2     With employees acting like it was high school ...
# 3     This place is a health hazard with the back ha...
# ...

# %%
serv['sentence']=serv['sentence'].str.replace('\n','')
serv
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence   annotation
# 0       Gross how can anyone serve food from a pig pen.      Service
# 1      I would not feed my dogs from this nasty so c...  Not_Service
# 2     With employees acting like it was high school ...      Service
# 3     This place is a health hazard with the back ha...      Service
# 4     Amd mike the guy on the register giving food a...      Service
# 5                 Don't get me wrong, I love Taco Bell.  Not_Service
# 6                          This Taco Bell, not so much.  Not_Service
# ...

# %%
price['sentence']=price['sentence'].str.replace('\n','')
price
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Price
# 1      I would not feed my dogs from this nasty so c...  Not_Price
# 2     With employees acting like it was high school ...  Not_Price
# 3     This place is a health hazard with the back ha...  Not_Price
# 4     Amd mike the guy on the register giving food a...  Not_Price
# 5                 Don't get me wrong, I love Taco Bell.  Not_Price
# 6                          This Taco Bell, not so much.  Not_Price
# 7     It's hard to go anywhere when the people that ...  Not_Price
# ...

# %%
food['sentence']=food['sentence'].str.replace('\n','')
food
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.   Not_Food
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...   Not_Food
# 3     This place is a health hazard with the back ha...   Not_Food
# 4     Amd mike the guy on the register giving food a...   Not_Food
# 5                 Don't get me wrong, I love Taco Bell.   Not_Food
# 6                          This Taco Bell, not so much.   Not_Food
# 7     It's hard to go anywhere when the people that ...   Not_Food
# ...

# %%
other['sentence']=other['sentence'].str.replace('\n','')
other
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Other
# 1      I would not feed my dogs from this nasty so c...  Not_Other
# 2     With employees acting like it was high school ...  Not_Other
# 3     This place is a health hazard with the back ha...  Not_Other
# 4     Amd mike the guy on the register giving food a...  Not_Other
# 5                 Don't get me wrong, I love Taco Bell.      Other
# 6                          This Taco Bell, not so much.      Other
# 7     It's hard to go anywhere when the people that ...      Other
# ...

# %%
abm['sentence']=abm['sentence'].str.replace('\n','')
abm
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Ambience
# 1      I would not feed my dogs from this nasty so c...  Not_Ambience
# 2     With employees acting like it was high school ...  Not_Ambience
# 3     This place is a health hazard with the back ha...  Not_Ambience
# 4     Amd mike the guy on the register giving food a...  Not_Ambience
# 5                 Don't get me wrong, I love Taco Bell.  Not_Ambience
# 6                          This Taco Bell, not so much.  Not_Ambience
# ...

# %%
loc['sentence']=loc['sentence'].str.replace('\n','')
loc
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation
# 0       Gross how can anyone serve food from a pig pen.  Not_Location
# 1      I would not feed my dogs from this nasty so c...  Not_Location
# 2     With employees acting like it was high school ...  Not_Location
# 3     This place is a health hazard with the back ha...  Not_Location
# 4     Amd mike the guy on the register giving food a...  Not_Location
# 5                 Don't get me wrong, I love Taco Bell.  Not_Location
# 6                          This Taco Bell, not so much.  Not_Location
# ...

# %%
park['sentence']=park['sentence'].str.replace('\n','')
park
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence  \
# 0       Gross how can anyone serve food from a pig pen.
# 1      I would not feed my dogs from this nasty so c...
# 2     With employees acting like it was high school ...
# 3     This place is a health hazard with the back ha...
# 4     Amd mike the guy on the register giving food a...
# 5                 Don't get me wrong, I love Taco Bell.
# 6                          This Taco Bell, not so much.
# 7     It's hard to go anywhere when the people that ...
# 8      Have some pride in what you do even if it's n...
# ...

# %%
import string
serv['sentence-removedpunc'] = serv['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
serv
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                                sentence   annotation  \
# 0       Gross how can anyone serve food from a pig pen.      Service
# 1      I would not feed my dogs from this nasty so c...  Not_Service
# 2     With employees acting like it was high school ...      Service
# 3     This place is a health hazard with the back ha...      Service
# 4     Amd mike the guy on the register giving food a...      Service
# 5                 Don't get me wrong, I love Taco Bell.  Not_Service
# 6                          This Taco Bell, not so much.  Not_Service
# ...

# %%
price['sentence-removedpunc'] = price['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
price
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation  \
# 0       Gross how can anyone serve food from a pig pen.  Not_Price
# 1      I would not feed my dogs from this nasty so c...  Not_Price
# 2     With employees acting like it was high school ...  Not_Price
# 3     This place is a health hazard with the back ha...  Not_Price
# 4     Amd mike the guy on the register giving food a...  Not_Price
# 5                 Don't get me wrong, I love Taco Bell.  Not_Price
# 6                          This Taco Bell, not so much.  Not_Price
# ...

# %%
food['sentence-removedpunc'] = food['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
food
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation  \
# 0       Gross how can anyone serve food from a pig pen.   Not_Food
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...   Not_Food
# 3     This place is a health hazard with the back ha...   Not_Food
# 4     Amd mike the guy on the register giving food a...   Not_Food
# 5                 Don't get me wrong, I love Taco Bell.   Not_Food
# 6                          This Taco Bell, not so much.   Not_Food
# ...

# %%
other['sentence-removedpunc'] = other['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
other
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation  \
# 0       Gross how can anyone serve food from a pig pen.  Not_Other
# 1      I would not feed my dogs from this nasty so c...  Not_Other
# 2     With employees acting like it was high school ...  Not_Other
# 3     This place is a health hazard with the back ha...  Not_Other
# 4     Amd mike the guy on the register giving food a...  Not_Other
# 5                 Don't get me wrong, I love Taco Bell.      Other
# 6                          This Taco Bell, not so much.      Other
# ...

# %%
abm['sentence-removedpunc'] = abm['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
abm
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation  \
# 0       Gross how can anyone serve food from a pig pen.  Not_Ambience
# 1      I would not feed my dogs from this nasty so c...  Not_Ambience
# 2     With employees acting like it was high school ...  Not_Ambience
# 3     This place is a health hazard with the back ha...  Not_Ambience
# 4     Amd mike the guy on the register giving food a...  Not_Ambience
# 5                 Don't get me wrong, I love Taco Bell.  Not_Ambience
# 6                          This Taco Bell, not so much.  Not_Ambience
# ...

# %%
loc['sentence-removedpunc'] = loc['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
loc
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation  \
# 0       Gross how can anyone serve food from a pig pen.  Not_Location
# 1      I would not feed my dogs from this nasty so c...  Not_Location
# 2     With employees acting like it was high school ...  Not_Location
# 3     This place is a health hazard with the back ha...  Not_Location
# 4     Amd mike the guy on the register giving food a...  Not_Location
# 5                 Don't get me wrong, I love Taco Bell.  Not_Location
# 6                          This Taco Bell, not so much.  Not_Location
# ...

# %%
park['sentence-removedpunc'] = park['sentence'].astype(str).apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
park
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence  \
# 0       Gross how can anyone serve food from a pig pen.
# 1      I would not feed my dogs from this nasty so c...
# 2     With employees acting like it was high school ...
# 3     This place is a health hazard with the back ha...
# 4     Amd mike the guy on the register giving food a...
# 5                 Don't get me wrong, I love Taco Bell.
# 6                          This Taco Bell, not so much.
# 7     It's hard to go anywhere when the people that ...
# 8      Have some pride in what you do even if it's n...
# ...

# %%
serv1=serv[['sentence-removedpunc','annotation']]
serv1
# Out:
#                                    sentence-removedpunc   annotation
# 0        Gross how can anyone serve food from a pig pen      Service
# 1      I would not feed my dogs from this nasty so c...  Not_Service
# 2     With employees acting like it was high school ...      Service
# 3     This place is a health hazard with the back ha...      Service
# 4     Amd mike the guy on the register giving food a...      Service
# 5                    Dont get me wrong I love Taco Bell  Not_Service
# 6                            This Taco Bell not so much  Not_Service
# 7     Its hard to go anywhere when the people that w...  Not_Service
# 8      Have some pride in what you do even if its no...  Not_Service
# 9     I will drive quickly past this Taco Bell to ge...  Not_Service
# 10          Im a definite fan of this Taco Bell in fact  Not_Service
# 11    I secretly drive past one Taco Bell to go to t...  Not_Service
# 12    I dont know if it is the newness of the buildi...  Not_Service
# ...

# %%
price1=price[['sentence-removedpunc','annotation']]
price1
# Out:
#                                    sentence-removedpunc annotation
# 0        Gross how can anyone serve food from a pig pen  Not_Price
# 1      I would not feed my dogs from this nasty so c...  Not_Price
# 2     With employees acting like it was high school ...  Not_Price
# 3     This place is a health hazard with the back ha...  Not_Price
# 4     Amd mike the guy on the register giving food a...  Not_Price
# 5                    Dont get me wrong I love Taco Bell  Not_Price
# 6                            This Taco Bell not so much  Not_Price
# 7     Its hard to go anywhere when the people that w...  Not_Price
# 8      Have some pride in what you do even if its no...  Not_Price
# 9     I will drive quickly past this Taco Bell to ge...  Not_Price
# 10          Im a definite fan of this Taco Bell in fact  Not_Price
# 11    I secretly drive past one Taco Bell to go to t...  Not_Price
# 12    I dont know if it is the newness of the buildi...  Not_Price
# ...

# %%
food1=food[['sentence-removedpunc','annotation']]
food1
# Out:
#                                    sentence-removedpunc annotation
# 0        Gross how can anyone serve food from a pig pen   Not_Food
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...   Not_Food
# 3     This place is a health hazard with the back ha...   Not_Food
# 4     Amd mike the guy on the register giving food a...   Not_Food
# 5                    Dont get me wrong I love Taco Bell   Not_Food
# 6                            This Taco Bell not so much   Not_Food
# 7     Its hard to go anywhere when the people that w...   Not_Food
# 8      Have some pride in what you do even if its no...   Not_Food
# 9     I will drive quickly past this Taco Bell to ge...   Not_Food
# 10          Im a definite fan of this Taco Bell in fact   Not_Food
# 11    I secretly drive past one Taco Bell to go to t...   Not_Food
# 12    I dont know if it is the newness of the buildi...   Not_Food
# ...

# %%
other1=other[['sentence-removedpunc','annotation']]
other1
# Out:
#                                    sentence-removedpunc annotation
# 0        Gross how can anyone serve food from a pig pen  Not_Other
# 1      I would not feed my dogs from this nasty so c...  Not_Other
# 2     With employees acting like it was high school ...  Not_Other
# 3     This place is a health hazard with the back ha...  Not_Other
# 4     Amd mike the guy on the register giving food a...  Not_Other
# 5                    Dont get me wrong I love Taco Bell      Other
# 6                            This Taco Bell not so much      Other
# 7     Its hard to go anywhere when the people that w...      Other
# 8      Have some pride in what you do even if its no...      Other
# 9     I will drive quickly past this Taco Bell to ge...      Other
# 10          Im a definite fan of this Taco Bell in fact      Other
# 11    I secretly drive past one Taco Bell to go to t...      Other
# 12    I dont know if it is the newness of the buildi...  Not_Other
# ...

# %%
abm1=abm[['sentence-removedpunc','annotation']]
abm1
# Out:
#                                    sentence-removedpunc    annotation
# 0        Gross how can anyone serve food from a pig pen  Not_Ambience
# 1      I would not feed my dogs from this nasty so c...  Not_Ambience
# 2     With employees acting like it was high school ...  Not_Ambience
# 3     This place is a health hazard with the back ha...  Not_Ambience
# 4     Amd mike the guy on the register giving food a...  Not_Ambience
# 5                    Dont get me wrong I love Taco Bell  Not_Ambience
# 6                            This Taco Bell not so much  Not_Ambience
# 7     Its hard to go anywhere when the people that w...  Not_Ambience
# 8      Have some pride in what you do even if its no...  Not_Ambience
# 9     I will drive quickly past this Taco Bell to ge...  Not_Ambience
# 10          Im a definite fan of this Taco Bell in fact  Not_Ambience
# 11    I secretly drive past one Taco Bell to go to t...  Not_Ambience
# ...

# %%
loc1=loc[['sentence-removedpunc','annotation']]
loc1
# Out:
#                                    sentence-removedpunc    annotation
# 0        Gross how can anyone serve food from a pig pen  Not_Location
# 1      I would not feed my dogs from this nasty so c...  Not_Location
# 2     With employees acting like it was high school ...  Not_Location
# 3     This place is a health hazard with the back ha...  Not_Location
# 4     Amd mike the guy on the register giving food a...  Not_Location
# 5                    Dont get me wrong I love Taco Bell  Not_Location
# 6                            This Taco Bell not so much  Not_Location
# 7     Its hard to go anywhere when the people that w...  Not_Location
# 8      Have some pride in what you do even if its no...  Not_Location
# 9     I will drive quickly past this Taco Bell to ge...  Not_Location
# 10          Im a definite fan of this Taco Bell in fact  Not_Location
# 11    I secretly drive past one Taco Bell to go to t...  Not_Location
# ...

# %%
park1=park[['sentence-removedpunc','annotation']]
park1
# Out:
#                                    sentence-removedpunc  \
# 0        Gross how can anyone serve food from a pig pen
# 1      I would not feed my dogs from this nasty so c...
# 2     With employees acting like it was high school ...
# 3     This place is a health hazard with the back ha...
# 4     Amd mike the guy on the register giving food a...
# 5                    Dont get me wrong I love Taco Bell
# 6                            This Taco Bell not so much
# 7     Its hard to go anywhere when the people that w...
# 8      Have some pride in what you do even if its no...
# 9     I will drive quickly past this Taco Bell to ge...
# 10          Im a definite fan of this Taco Bell in fact
# 11    I secretly drive past one Taco Bell to go to t...
# 12    I dont know if it is the newness of the buildi...
# 13     Everything is kept really clean and the insid...
# 14    My one complaint is that in their attempt to m...
# 15     Not that there is ever a huge line here which...
# ...

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
serv1['sentence-convlower'] = serv1['sentence-removedpunc'].str.lower()
serv1
# Out:
#                                    sentence-removedpunc   annotation  \
# 0        Gross how can anyone serve food from a pig pen      Service
# 1      I would not feed my dogs from this nasty so c...  Not_Service
# 2     With employees acting like it was high school ...      Service
# 3     This place is a health hazard with the back ha...      Service
# 4     Amd mike the guy on the register giving food a...      Service
# 5                    Dont get me wrong I love Taco Bell  Not_Service
# 6                            This Taco Bell not so much  Not_Service
# 7     Its hard to go anywhere when the people that w...  Not_Service
# 8      Have some pride in what you do even if its no...  Not_Service
# 9     I will drive quickly past this Taco Bell to ge...  Not_Service
# 10          Im a definite fan of this Taco Bell in fact  Not_Service
# 11    I secretly drive past one Taco Bell to go to t...  Not_Service
# 12    I dont know if it is the newness of the buildi...  Not_Service
# ...

# %%
stop = stopwords.words('english')
price1['sentence-convlower'] = price1['sentence-removedpunc'].str.lower()
price1
# Out:
#                                    sentence-removedpunc annotation  \
# 0        Gross how can anyone serve food from a pig pen  Not_Price
# 1      I would not feed my dogs from this nasty so c...  Not_Price
# 2     With employees acting like it was high school ...  Not_Price
# 3     This place is a health hazard with the back ha...  Not_Price
# 4     Amd mike the guy on the register giving food a...  Not_Price
# 5                    Dont get me wrong I love Taco Bell  Not_Price
# 6                            This Taco Bell not so much  Not_Price
# 7     Its hard to go anywhere when the people that w...  Not_Price
# 8      Have some pride in what you do even if its no...  Not_Price
# 9     I will drive quickly past this Taco Bell to ge...  Not_Price
# 10          Im a definite fan of this Taco Bell in fact  Not_Price
# 11    I secretly drive past one Taco Bell to go to t...  Not_Price
# 12    I dont know if it is the newness of the buildi...  Not_Price
# ...

# %%
food1['sentence-convlower'] = food1['sentence-removedpunc'].str.lower()
food1
# Out:
#                                    sentence-removedpunc annotation  \
# 0        Gross how can anyone serve food from a pig pen   Not_Food
# 1      I would not feed my dogs from this nasty so c...       Food
# 2     With employees acting like it was high school ...   Not_Food
# 3     This place is a health hazard with the back ha...   Not_Food
# 4     Amd mike the guy on the register giving food a...   Not_Food
# 5                    Dont get me wrong I love Taco Bell   Not_Food
# 6                            This Taco Bell not so much   Not_Food
# 7     Its hard to go anywhere when the people that w...   Not_Food
# 8      Have some pride in what you do even if its no...   Not_Food
# 9     I will drive quickly past this Taco Bell to ge...   Not_Food
# 10          Im a definite fan of this Taco Bell in fact   Not_Food
# 11    I secretly drive past one Taco Bell to go to t...   Not_Food
# 12    I dont know if it is the newness of the buildi...   Not_Food
# ...

# %%
other1['sentence-convlower'] = other1['sentence-removedpunc'].str.lower()
other1
# Out:
#                                    sentence-removedpunc annotation  \
# 0        Gross how can anyone serve food from a pig pen  Not_Other
# 1      I would not feed my dogs from this nasty so c...  Not_Other
# 2     With employees acting like it was high school ...  Not_Other
# 3     This place is a health hazard with the back ha...  Not_Other
# 4     Amd mike the guy on the register giving food a...  Not_Other
# 5                    Dont get me wrong I love Taco Bell      Other
# 6                            This Taco Bell not so much      Other
# 7     Its hard to go anywhere when the people that w...      Other
# 8      Have some pride in what you do even if its no...      Other
# 9     I will drive quickly past this Taco Bell to ge...      Other
# 10          Im a definite fan of this Taco Bell in fact      Other
# 11    I secretly drive past one Taco Bell to go to t...      Other
# 12    I dont know if it is the newness of the buildi...  Not_Other
# ...

# %%
abm1['sentence-convlower'] = abm1['sentence-removedpunc'].str.lower()
abm1
# Out:
#                                    sentence-removedpunc    annotation  \
# 0        Gross how can anyone serve food from a pig pen  Not_Ambience
# 1      I would not feed my dogs from this nasty so c...  Not_Ambience
# 2     With employees acting like it was high school ...  Not_Ambience
# 3     This place is a health hazard with the back ha...  Not_Ambience
# 4     Amd mike the guy on the register giving food a...  Not_Ambience
# 5                    Dont get me wrong I love Taco Bell  Not_Ambience
# 6                            This Taco Bell not so much  Not_Ambience
# 7     Its hard to go anywhere when the people that w...  Not_Ambience
# 8      Have some pride in what you do even if its no...  Not_Ambience
# 9     I will drive quickly past this Taco Bell to ge...  Not_Ambience
# 10          Im a definite fan of this Taco Bell in fact  Not_Ambience
# 11    I secretly drive past one Taco Bell to go to t...  Not_Ambience
# ...

# %%
loc1['sentence-convlower'] = loc1['sentence-removedpunc'].str.lower()
loc1
# Out:
#                                    sentence-removedpunc    annotation  \
# 0        Gross how can anyone serve food from a pig pen  Not_Location
# 1      I would not feed my dogs from this nasty so c...  Not_Location
# 2     With employees acting like it was high school ...  Not_Location
# 3     This place is a health hazard with the back ha...  Not_Location
# 4     Amd mike the guy on the register giving food a...  Not_Location
# 5                    Dont get me wrong I love Taco Bell  Not_Location
# 6                            This Taco Bell not so much  Not_Location
# 7     Its hard to go anywhere when the people that w...  Not_Location
# 8      Have some pride in what you do even if its no...  Not_Location
# 9     I will drive quickly past this Taco Bell to ge...  Not_Location
# 10          Im a definite fan of this Taco Bell in fact  Not_Location
# 11    I secretly drive past one Taco Bell to go to t...  Not_Location
# ...

# %%
park1['sentence-convlower'] = park1['sentence-removedpunc'].str.lower()
park1
# Out:
#                                    sentence-removedpunc  \
# 0        Gross how can anyone serve food from a pig pen
# 1      I would not feed my dogs from this nasty so c...
# 2     With employees acting like it was high school ...
# 3     This place is a health hazard with the back ha...
# 4     Amd mike the guy on the register giving food a...
# 5                    Dont get me wrong I love Taco Bell
# 6                            This Taco Bell not so much
# 7     Its hard to go anywhere when the people that w...
# 8      Have some pride in what you do even if its no...
# 9     I will drive quickly past this Taco Bell to ge...
# 10          Im a definite fan of this Taco Bell in fact
# 11    I secretly drive past one Taco Bell to go to t...
# 12    I dont know if it is the newness of the buildi...
# 13     Everything is kept really clean and the insid...
# 14    My one complaint is that in their attempt to m...
# 15     Not that there is ever a huge line here which...
# ...

# %%
serv2=serv1[['sentence-convlower','annotation']]
serv2
# Out:
#                                      sentence-convlower   annotation
# 0        gross how can anyone serve food from a pig pen      Service
# 1      i would not feed my dogs from this nasty so c...  Not_Service
# 2     with employees acting like it was high school ...      Service
# 3     this place is a health hazard with the back ha...      Service
# 4     amd mike the guy on the register giving food a...      Service
# 5                    dont get me wrong i love taco bell  Not_Service
# 6                            this taco bell not so much  Not_Service
# 7     its hard to go anywhere when the people that w...  Not_Service
# 8      have some pride in what you do even if its no...  Not_Service
# 9     i will drive quickly past this taco bell to ge...  Not_Service
# 10          im a definite fan of this taco bell in fact  Not_Service
# 11    i secretly drive past one taco bell to go to t...  Not_Service
# 12    i dont know if it is the newness of the buildi...  Not_Service
# ...

# %%
price2=price1[['sentence-convlower','annotation']]
price2
# Out:
#                                      sentence-convlower annotation
# 0        gross how can anyone serve food from a pig pen  Not_Price
# 1      i would not feed my dogs from this nasty so c...  Not_Price
# 2     with employees acting like it was high school ...  Not_Price
# 3     this place is a health hazard with the back ha...  Not_Price
# 4     amd mike the guy on the register giving food a...  Not_Price
# 5                    dont get me wrong i love taco bell  Not_Price
# 6                            this taco bell not so much  Not_Price
# 7     its hard to go anywhere when the people that w...  Not_Price
# 8      have some pride in what you do even if its no...  Not_Price
# 9     i will drive quickly past this taco bell to ge...  Not_Price
# 10          im a definite fan of this taco bell in fact  Not_Price
# 11    i secretly drive past one taco bell to go to t...  Not_Price
# 12    i dont know if it is the newness of the buildi...  Not_Price
# ...

# %%
food2=food1[['sentence-convlower','annotation']]
food2
# Out:
#                                      sentence-convlower annotation
# 0        gross how can anyone serve food from a pig pen   Not_Food
# 1      i would not feed my dogs from this nasty so c...       Food
# 2     with employees acting like it was high school ...   Not_Food
# 3     this place is a health hazard with the back ha...   Not_Food
# 4     amd mike the guy on the register giving food a...   Not_Food
# 5                    dont get me wrong i love taco bell   Not_Food
# 6                            this taco bell not so much   Not_Food
# 7     its hard to go anywhere when the people that w...   Not_Food
# 8      have some pride in what you do even if its no...   Not_Food
# 9     i will drive quickly past this taco bell to ge...   Not_Food
# 10          im a definite fan of this taco bell in fact   Not_Food
# 11    i secretly drive past one taco bell to go to t...   Not_Food
# 12    i dont know if it is the newness of the buildi...   Not_Food
# ...

# %%
other2=other1[['sentence-convlower','annotation']]
other2
# Out:
#                                      sentence-convlower annotation
# 0        gross how can anyone serve food from a pig pen  Not_Other
# 1      i would not feed my dogs from this nasty so c...  Not_Other
# 2     with employees acting like it was high school ...  Not_Other
# 3     this place is a health hazard with the back ha...  Not_Other
# 4     amd mike the guy on the register giving food a...  Not_Other
# 5                    dont get me wrong i love taco bell      Other
# 6                            this taco bell not so much      Other
# 7     its hard to go anywhere when the people that w...      Other
# 8      have some pride in what you do even if its no...      Other
# 9     i will drive quickly past this taco bell to ge...      Other
# 10          im a definite fan of this taco bell in fact      Other
# 11    i secretly drive past one taco bell to go to t...      Other
# 12    i dont know if it is the newness of the buildi...  Not_Other
# ...

# %%
abm2=abm1[['sentence-convlower','annotation']]
abm2
# Out:
#                                      sentence-convlower    annotation
# 0        gross how can anyone serve food from a pig pen  Not_Ambience
# 1      i would not feed my dogs from this nasty so c...  Not_Ambience
# 2     with employees acting like it was high school ...  Not_Ambience
# 3     this place is a health hazard with the back ha...  Not_Ambience
# 4     amd mike the guy on the register giving food a...  Not_Ambience
# 5                    dont get me wrong i love taco bell  Not_Ambience
# 6                            this taco bell not so much  Not_Ambience
# 7     its hard to go anywhere when the people that w...  Not_Ambience
# 8      have some pride in what you do even if its no...  Not_Ambience
# 9     i will drive quickly past this taco bell to ge...  Not_Ambience
# 10          im a definite fan of this taco bell in fact  Not_Ambience
# 11    i secretly drive past one taco bell to go to t...  Not_Ambience
# ...

# %%
loc2=loc1[['sentence-convlower','annotation']]
loc2
# Out:
#                                      sentence-convlower    annotation
# 0        gross how can anyone serve food from a pig pen  Not_Location
# 1      i would not feed my dogs from this nasty so c...  Not_Location
# 2     with employees acting like it was high school ...  Not_Location
# 3     this place is a health hazard with the back ha...  Not_Location
# 4     amd mike the guy on the register giving food a...  Not_Location
# 5                    dont get me wrong i love taco bell  Not_Location
# 6                            this taco bell not so much  Not_Location
# 7     its hard to go anywhere when the people that w...  Not_Location
# 8      have some pride in what you do even if its no...  Not_Location
# 9     i will drive quickly past this taco bell to ge...  Not_Location
# 10          im a definite fan of this taco bell in fact  Not_Location
# 11    i secretly drive past one taco bell to go to t...  Not_Location
# ...

# %%
park2=park1[['sentence-convlower','annotation']]
park2
# Out:
#                                      sentence-convlower  \
# 0        gross how can anyone serve food from a pig pen
# 1      i would not feed my dogs from this nasty so c...
# 2     with employees acting like it was high school ...
# 3     this place is a health hazard with the back ha...
# 4     amd mike the guy on the register giving food a...
# 5                    dont get me wrong i love taco bell
# 6                            this taco bell not so much
# 7     its hard to go anywhere when the people that w...
# 8      have some pride in what you do even if its no...
# 9     i will drive quickly past this taco bell to ge...
# 10          im a definite fan of this taco bell in fact
# 11    i secretly drive past one taco bell to go to t...
# 12    i dont know if it is the newness of the buildi...
# 13     everything is kept really clean and the insid...
# 14    my one complaint is that in their attempt to m...
# 15     not that there is ever a huge line here which...
# ...

# %%
serv2['sentence'] = serv2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
serv2=serv2[['sentence','annotation']]
serv2
# Out:
#                                                sentence   annotation
# 0                [gross, anyone, serve, food, pig, pen]      Service
# 1      [, would, feed, dogs, nasty, called, restaurant]  Not_Service
# 2     [employees, acting, like, high, school, runnin...      Service
# 3       [place, health, hazard, back, food, everywhere]      Service
# 4     [amd, mike, guy, register, giving, food, away,...      Service
# 5                  [dont, get, wrong, love, taco, bell]  Not_Service
# 6                                    [taco, bell, much]  Not_Service
# 7     [hard, go, anywhere, people, work, obviously, ...  Not_Service
# 8               [, pride, even, endallbeall, existence]  Not_Service
# 9     [drive, quickly, past, taco, bell, get, better...  Not_Service
# 10                [im, definite, fan, taco, bell, fact]  Not_Service
# 11    [secretly, drive, past, one, taco, bell, go, one]  Not_Service
# 12    [dont, know, newness, building, shopping, comp...  Not_Service
# ...

# %%
price2['sentence'] = price2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
price2=price2[['sentence','annotation']]
price2
# Out:
#                                                sentence annotation
# 0                [gross, anyone, serve, food, pig, pen]  Not_Price
# 1      [, would, feed, dogs, nasty, called, restaurant]  Not_Price
# 2     [employees, acting, like, high, school, runnin...  Not_Price
# 3       [place, health, hazard, back, food, everywhere]  Not_Price
# 4     [amd, mike, guy, register, giving, food, away,...  Not_Price
# 5                  [dont, get, wrong, love, taco, bell]  Not_Price
# 6                                    [taco, bell, much]  Not_Price
# 7     [hard, go, anywhere, people, work, obviously, ...  Not_Price
# 8               [, pride, even, endallbeall, existence]  Not_Price
# 9     [drive, quickly, past, taco, bell, get, better...  Not_Price
# 10                [im, definite, fan, taco, bell, fact]  Not_Price
# 11    [secretly, drive, past, one, taco, bell, go, one]  Not_Price
# 12    [dont, know, newness, building, shopping, comp...  Not_Price
# ...

# %%
food2['sentence'] = food2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
food2=food2[['sentence','annotation']]
food2
# Out:
#                                                sentence annotation
# 0                [gross, anyone, serve, food, pig, pen]   Not_Food
# 1      [, would, feed, dogs, nasty, called, restaurant]       Food
# 2     [employees, acting, like, high, school, runnin...   Not_Food
# 3       [place, health, hazard, back, food, everywhere]   Not_Food
# 4     [amd, mike, guy, register, giving, food, away,...   Not_Food
# 5                  [dont, get, wrong, love, taco, bell]   Not_Food
# 6                                    [taco, bell, much]   Not_Food
# 7     [hard, go, anywhere, people, work, obviously, ...   Not_Food
# 8               [, pride, even, endallbeall, existence]   Not_Food
# 9     [drive, quickly, past, taco, bell, get, better...   Not_Food
# 10                [im, definite, fan, taco, bell, fact]   Not_Food
# 11    [secretly, drive, past, one, taco, bell, go, one]   Not_Food
# 12    [dont, know, newness, building, shopping, comp...   Not_Food
# ...

# %%
other2['sentence'] = other2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
other2=other2[['sentence','annotation']]
other2
# Out:
#                                                sentence annotation
# 0                [gross, anyone, serve, food, pig, pen]  Not_Other
# 1      [, would, feed, dogs, nasty, called, restaurant]  Not_Other
# 2     [employees, acting, like, high, school, runnin...  Not_Other
# 3       [place, health, hazard, back, food, everywhere]  Not_Other
# 4     [amd, mike, guy, register, giving, food, away,...  Not_Other
# 5                  [dont, get, wrong, love, taco, bell]      Other
# 6                                    [taco, bell, much]      Other
# 7     [hard, go, anywhere, people, work, obviously, ...      Other
# 8               [, pride, even, endallbeall, existence]      Other
# 9     [drive, quickly, past, taco, bell, get, better...      Other
# 10                [im, definite, fan, taco, bell, fact]      Other
# 11    [secretly, drive, past, one, taco, bell, go, one]      Other
# 12    [dont, know, newness, building, shopping, comp...  Not_Other
# ...

# %%
abm2['sentence'] = abm2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
abm2=abm2[['sentence','annotation']]
abm2
# Out:
#                                                sentence    annotation
# 0                [gross, anyone, serve, food, pig, pen]  Not_Ambience
# 1      [, would, feed, dogs, nasty, called, restaurant]  Not_Ambience
# 2     [employees, acting, like, high, school, runnin...  Not_Ambience
# 3       [place, health, hazard, back, food, everywhere]  Not_Ambience
# 4     [amd, mike, guy, register, giving, food, away,...  Not_Ambience
# 5                  [dont, get, wrong, love, taco, bell]  Not_Ambience
# 6                                    [taco, bell, much]  Not_Ambience
# 7     [hard, go, anywhere, people, work, obviously, ...  Not_Ambience
# 8               [, pride, even, endallbeall, existence]  Not_Ambience
# 9     [drive, quickly, past, taco, bell, get, better...  Not_Ambience
# 10                [im, definite, fan, taco, bell, fact]  Not_Ambience
# 11    [secretly, drive, past, one, taco, bell, go, one]  Not_Ambience
# ...

# %%
loc2['sentence'] = loc2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
loc2=loc2[['sentence','annotation']]
loc2
# Out:
#                                                sentence    annotation
# 0                [gross, anyone, serve, food, pig, pen]  Not_Location
# 1      [, would, feed, dogs, nasty, called, restaurant]  Not_Location
# 2     [employees, acting, like, high, school, runnin...  Not_Location
# 3       [place, health, hazard, back, food, everywhere]  Not_Location
# 4     [amd, mike, guy, register, giving, food, away,...  Not_Location
# 5                  [dont, get, wrong, love, taco, bell]  Not_Location
# 6                                    [taco, bell, much]  Not_Location
# 7     [hard, go, anywhere, people, work, obviously, ...  Not_Location
# 8               [, pride, even, endallbeall, existence]  Not_Location
# 9     [drive, quickly, past, taco, bell, get, better...  Not_Location
# 10                [im, definite, fan, taco, bell, fact]  Not_Location
# 11    [secretly, drive, past, one, taco, bell, go, one]  Not_Location
# ...

# %%
park2['sentence'] = park2['sentence-convlower'].apply(lambda x: [item for item in x.split(' ') if item not in stop])
park2=park2[['sentence','annotation']]
park2
# Out:
#                                                sentence  \
# 0                [gross, anyone, serve, food, pig, pen]
# 1      [, would, feed, dogs, nasty, called, restaurant]
# 2     [employees, acting, like, high, school, runnin...
# 3       [place, health, hazard, back, food, everywhere]
# 4     [amd, mike, guy, register, giving, food, away,...
# 5                  [dont, get, wrong, love, taco, bell]
# 6                                    [taco, bell, much]
# 7     [hard, go, anywhere, people, work, obviously, ...
# 8               [, pride, even, endallbeall, existence]
# 9     [drive, quickly, past, taco, bell, get, better...
# 10                [im, definite, fan, taco, bell, fact]
# 11    [secretly, drive, past, one, taco, bell, go, one]
# 12    [dont, know, newness, building, shopping, comp...
# 13    [, everything, kept, really, clean, inside, re...
# 14    [one, complaint, attempt, make, interior, mode...
# 15    [, ever, huge, line, also, plus, makes, free, ...
# ...

# %%
serv2['sentence'] = serv2['sentence'].apply(lambda x:' '.join([i for i in x]))
serv2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence   annotation
# 0                       gross anyone serve food pig pen      Service
# 1               would feed dogs nasty called restaurant  Not_Service
# 2     employees acting like high school running manager      Service
# 3              place health hazard back food everywhere      Service
# 4     amd mike guy register giving food away friends...      Service
# 5                         dont get wrong love taco bell  Not_Service
# 6                                        taco bell much  Not_Service
# ...

# %%
price2['sentence'] = price2['sentence'].apply(lambda x:' '.join([i for i in x]))
price2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0                       gross anyone serve food pig pen  Not_Price
# 1               would feed dogs nasty called restaurant  Not_Price
# 2     employees acting like high school running manager  Not_Price
# 3              place health hazard back food everywhere  Not_Price
# 4     amd mike guy register giving food away friends...  Not_Price
# 5                         dont get wrong love taco bell  Not_Price
# 6                                        taco bell much  Not_Price
# 7     hard go anywhere people work obviously dont gi...  Not_Price
# ...

# %%
food2['sentence'] = food2['sentence'].apply(lambda x:' '.join([i for i in x]))
food2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0                       gross anyone serve food pig pen   Not_Food
# 1               would feed dogs nasty called restaurant       Food
# 2     employees acting like high school running manager   Not_Food
# 3              place health hazard back food everywhere   Not_Food
# 4     amd mike guy register giving food away friends...   Not_Food
# 5                         dont get wrong love taco bell   Not_Food
# 6                                        taco bell much   Not_Food
# 7     hard go anywhere people work obviously dont gi...   Not_Food
# ...

# %%
other2['sentence'] = other2['sentence'].apply(lambda x:' '.join([i for i in x]))
other2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence annotation
# 0                       gross anyone serve food pig pen  Not_Other
# 1               would feed dogs nasty called restaurant  Not_Other
# 2     employees acting like high school running manager  Not_Other
# 3              place health hazard back food everywhere  Not_Other
# 4     amd mike guy register giving food away friends...  Not_Other
# 5                         dont get wrong love taco bell      Other
# 6                                        taco bell much      Other
# 7     hard go anywhere people work obviously dont gi...      Other
# ...

# %%
abm2['sentence'] = abm2['sentence'].apply(lambda x:' '.join([i for i in x]))
abm2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation
# 0                       gross anyone serve food pig pen  Not_Ambience
# 1               would feed dogs nasty called restaurant  Not_Ambience
# 2     employees acting like high school running manager  Not_Ambience
# 3              place health hazard back food everywhere  Not_Ambience
# 4     amd mike guy register giving food away friends...  Not_Ambience
# 5                         dont get wrong love taco bell  Not_Ambience
# 6                                        taco bell much  Not_Ambience
# ...

# %%
loc2['sentence'] = loc2['sentence'].apply(lambda x:' '.join([i for i in x]))
loc2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence    annotation
# 0                       gross anyone serve food pig pen  Not_Location
# 1               would feed dogs nasty called restaurant  Not_Location
# 2     employees acting like high school running manager  Not_Location
# 3              place health hazard back food everywhere  Not_Location
# 4     amd mike guy register giving food away friends...  Not_Location
# 5                         dont get wrong love taco bell  Not_Location
# 6                                        taco bell much  Not_Location
# ...

# %%
park2['sentence'] = park2['sentence'].apply(lambda x:' '.join([i for i in x]))
park2
# Out:
# C:\Users\Rency\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                sentence  \
# 0                       gross anyone serve food pig pen
# 1               would feed dogs nasty called restaurant
# 2     employees acting like high school running manager
# 3              place health hazard back food everywhere
# 4     amd mike guy register giving food away friends...
# 5                         dont get wrong love taco bell
# 6                                        taco bell much
# 7     hard go anywhere people work obviously dont gi...
# 8                      pride even endallbeall existence
# ...

# %%
serv2_annotation_based=serv2[(serv2.annotation=='Service')|(serv2.annotation=='Not_Service')]
serv2_annotation_based
# Out:
#                                                sentence   annotation
# 0                       gross anyone serve food pig pen      Service
# 1               would feed dogs nasty called restaurant  Not_Service
# 2     employees acting like high school running manager      Service
# 3              place health hazard back food everywhere      Service
# 4     amd mike guy register giving food away friends...      Service
# 5                         dont get wrong love taco bell  Not_Service
# 6                                        taco bell much  Not_Service
# 7     hard go anywhere people work obviously dont gi...  Not_Service
# 8                      pride even endallbeall existence  Not_Service
# 9           drive quickly past taco bell get better one  Not_Service
# 10                       im definite fan taco bell fact  Not_Service
# 11             secretly drive past one taco bell go one  Not_Service
# 12    dont know newness building shopping complex iv...  Not_Service
# ...

# %%
price2_annotation_based=price2[(price2.annotation=='Price')|(price2.annotation=='Not_Price')]
price2_annotation_based
# Out:
#                                                sentence annotation
# 0                       gross anyone serve food pig pen  Not_Price
# 1               would feed dogs nasty called restaurant  Not_Price
# 2     employees acting like high school running manager  Not_Price
# 3              place health hazard back food everywhere  Not_Price
# 4     amd mike guy register giving food away friends...  Not_Price
# 5                         dont get wrong love taco bell  Not_Price
# 6                                        taco bell much  Not_Price
# 7     hard go anywhere people work obviously dont gi...  Not_Price
# 8                      pride even endallbeall existence  Not_Price
# 9           drive quickly past taco bell get better one  Not_Price
# 10                       im definite fan taco bell fact  Not_Price
# 11             secretly drive past one taco bell go one  Not_Price
# 12    dont know newness building shopping complex iv...  Not_Price
# ...

# %%
food2_annotation_based=food2[(food2.annotation=='Food')|(food2.annotation=='Not_Food')]
food2_annotation_based
# Out:
#                                                sentence annotation
# 0                       gross anyone serve food pig pen   Not_Food
# 1               would feed dogs nasty called restaurant       Food
# 2     employees acting like high school running manager   Not_Food
# 3              place health hazard back food everywhere   Not_Food
# 4     amd mike guy register giving food away friends...   Not_Food
# 5                         dont get wrong love taco bell   Not_Food
# 6                                        taco bell much   Not_Food
# 7     hard go anywhere people work obviously dont gi...   Not_Food
# 8                      pride even endallbeall existence   Not_Food
# 9           drive quickly past taco bell get better one   Not_Food
# 10                       im definite fan taco bell fact   Not_Food
# 11             secretly drive past one taco bell go one   Not_Food
# 12    dont know newness building shopping complex iv...   Not_Food
# ...

# %%
other2_annotation_based=other2[(other2.annotation=='Other')|(other2.annotation=='Not_Other')]
other2_annotation_based
# Out:
#                                                sentence annotation
# 0                       gross anyone serve food pig pen  Not_Other
# 1               would feed dogs nasty called restaurant  Not_Other
# 2     employees acting like high school running manager  Not_Other
# 3              place health hazard back food everywhere  Not_Other
# 4     amd mike guy register giving food away friends...  Not_Other
# 5                         dont get wrong love taco bell      Other
# 6                                        taco bell much      Other
# 7     hard go anywhere people work obviously dont gi...      Other
# 8                      pride even endallbeall existence      Other
# 9           drive quickly past taco bell get better one      Other
# 10                       im definite fan taco bell fact      Other
# 11             secretly drive past one taco bell go one      Other
# 12    dont know newness building shopping complex iv...  Not_Other
# ...

# %%
abm2_annotation_based=abm2[(abm2.annotation=='Ambience')|(abm2.annotation=='Not_Ambience')]
abm2_annotation_based
# Out:
#                                                sentence    annotation
# 0                       gross anyone serve food pig pen  Not_Ambience
# 1               would feed dogs nasty called restaurant  Not_Ambience
# 2     employees acting like high school running manager  Not_Ambience
# 3              place health hazard back food everywhere  Not_Ambience
# 4     amd mike guy register giving food away friends...  Not_Ambience
# 5                         dont get wrong love taco bell  Not_Ambience
# 6                                        taco bell much  Not_Ambience
# 7     hard go anywhere people work obviously dont gi...  Not_Ambience
# 8                      pride even endallbeall existence  Not_Ambience
# 9           drive quickly past taco bell get better one  Not_Ambience
# 10                       im definite fan taco bell fact  Not_Ambience
# 11             secretly drive past one taco bell go one  Not_Ambience
# ...

# %%
loc2_annotation_based=loc2[(loc2.annotation=='Location')|(loc2.annotation=='Not_Location')]
loc2_annotation_based
# Out:
#                                                sentence    annotation
# 0                       gross anyone serve food pig pen  Not_Location
# 1               would feed dogs nasty called restaurant  Not_Location
# 2     employees acting like high school running manager  Not_Location
# 3              place health hazard back food everywhere  Not_Location
# 4     amd mike guy register giving food away friends...  Not_Location
# 5                         dont get wrong love taco bell  Not_Location
# 6                                        taco bell much  Not_Location
# 7     hard go anywhere people work obviously dont gi...  Not_Location
# 8                      pride even endallbeall existence  Not_Location
# 9           drive quickly past taco bell get better one  Not_Location
# 10                       im definite fan taco bell fact  Not_Location
# 11             secretly drive past one taco bell go one  Not_Location
# ...

# %%
park2_annotation_based=park2[(park2.annotation=='Parking_availability')|(park2.annotation=='Not_Parking_availability')]
park2_annotation_based
# Out:
#                                                sentence  \
# 0                       gross anyone serve food pig pen
# 1               would feed dogs nasty called restaurant
# 2     employees acting like high school running manager
# 3              place health hazard back food everywhere
# 4     amd mike guy register giving food away friends...
# 5                         dont get wrong love taco bell
# 6                                        taco bell much
# 7     hard go anywhere people work obviously dont gi...
# 8                      pride even endallbeall existence
# 9           drive quickly past taco bell get better one
# 10                       im definite fan taco bell fact
# 11             secretly drive past one taco bell go one
# 12    dont know newness building shopping complex iv...
# 13     everything kept really clean inside really mo...
# 14    one complaint attempt make interior modern fro...
# 15     ever huge line also plus makes free happen ar...
# ...

# %%
import numpy as np
import scipy as sp
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-468-aa88a35d0429> in <module>()
#       6 from sklearn.linear_model import LogisticRegression
#       7 from sklearn import metrics
# ----> 8 from textblob import TextBlob, Word
#       9 from nltk.stem.snowball import SnowballStemmer
#
# ModuleNotFoundError: No module named 'textblob'

# %%
#from here - partitioning data for ASPECT - SERVICE
X_train_serv2, X_test_serv2, y_train_serv2, y_test_serv2 = train_test_split(serv2_annotation_based.sentence, serv2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_serv2 = vect.fit_transform(X_train_serv2)
test_dtm_serv2 = vect.transform(X_test_serv2)

# %%
train_dtm_serv2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_serv2 = vect.fit_transform(X_train_serv2)
train_dtm_serv2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_serv2 = TfidfTransformer()
tr_features_all_serv2 = tf_vec_all_serv2.fit_transform(train_dtm_serv2)
tr_features_all_serv2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_serv2 = vect.transform(X_test_serv2)
te_features_all_serv2 = tf_vec_all_serv2.transform(cte_features_all_serv2)
X_test_serv2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_serv2.shape))
# Out:
# (795, 5535)

# %%
# %matplotlib inline

import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import numpy as np
import scipy.sparse as sparse

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from nltk.corpus import stopwords
from sklearn.cross_validation import StratifiedKFold
from sklearn.naive_bayes import BernoulliNB
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import recall_score

# %%
models = {'BernoulliNB':BernoulliNB()
          ,'Logistic' : linear_model.LogisticRegression(C=1e5),'Perceptron': linear_model.Perceptron(n_iter=1000)}

# %%
#calculating accuracy, precision and recall for service. The next similar comment will calculate for others
results_all_bi_serv2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_serv2 = {}
cprediction_serv2 = {}
foldnum_serv2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_serv2, y_train_serv2)
        tfprediction_serv2[name] = model.predict(te_features_all_serv2)
        #print(tfprediction[name])
        tfaccuracy_serv2 = metrics.accuracy_score(tfprediction_serv2[name],y_test_serv2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_serv2.loc[foldnum_serv2,'TF-IDF Accuracy']=tfaccuracy_serv2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_serv2.loc[foldnum_serv2,'Model']=name
        foldnum_serv2 = foldnum_serv2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_serv2)
print (results_all_bi_serv2)
print (tfaccuracy_serv2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.683019  BernoulliNB
# 1         0.762264     Logistic
# 2         0.709434   Perceptron
# 0.709433962264

# %%
models1_serv2 = linear_model.LogisticRegression(C=1e5)
models1_serv2.fit(tr_features_all_serv2, y_train_serv2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_serv2 = models1_serv2.predict(te_features_all_serv2)
list(tfprediction_serv2)
# Out:
# ['Not_Service',
#  'Not_Service',
#  'Service',
#  'Service',
#  'Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Service',
#  'Service',
#  'Service',
#  'Service',
#  'Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Service',
#  'Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Not_Service',
#  'Service',
#  'Service',
#  'Service',
#  'Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
#  'Service',
#  'Service',
#  'Not_Service',
#  'Not_Service',
#  'Not_Service',
# ...

# %%
 from sklearn.metrics import precision_score

# %%
precision_serv2_MI=precision_score(y_test_serv2, tfprediction_serv2, average='micro')
print(precision_serv2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-547-c390a4051f27> in <module>()
# ----> 1 precision_serv2_MI=precision_score(y_test_serv2, tfprediction_serv2, average='micro')
#       2 print(precision_serv2)
#
# C:\Users\Rency\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#    1237                                                  average=average,
#    1238                                                  warn_for=('precision',),
# -> 1239                                                  sample_weight=sample_weight)
#    1240     return p
#    1241
#
# C:\Users\Rency\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
# ...

# %%
precision_serv2_MA=precision_score(y_test_serv2, tfprediction_serv2, average='macro')
print(precision_serv2_MA)
# Out:
# 0.728596349973

# %%
precision_serv2_WI=precision_score(y_test_serv2, tfprediction_serv2, average='weighted')
print(precision_serv2_WI)
# Out:
# 0.758995432403

# %%
precision_serv2_N= precision_score(y_test_serv2, tfprediction_serv2, average=None)
precision_serv2_N
# Out:
# array([ 0.81521739,  0.64197531])

# %%
from sklearn.metrics import recall_score
recall_serv2_MA=recall_score(y_test_serv2, tfprediction_serv2, average='macro')
recall_serv2_MA
# Out:
# 0.72131999480317011

# %%
recall_serv2_MI=recall_score(y_test_serv2, tfprediction_serv2, average='micro')
recall_serv2_MI
# Out:
# 0.76226415094339628

# %%
recall_serv2_WI=recall_score(y_test_serv2, tfprediction_serv2, average='weighted')
recall_serv2_WI
# Out:
# 0.76226415094339628

# %%
recall_serv2_N=recall_score(y_test_serv2, tfprediction_serv2, average=None)
recall_serv2_N
# Out:
# array([ 0.83798883,  0.60465116])

# %%
from sklearn.metrics import f1_score
f1_serv2_MI=f1_score(y_test_serv2, tfprediction_serv2, average='micro')
print(f1_serv2_MI)
# Out:
# 0.762264150943

# %%
f1_serv2_MA=f1_score(y_test_serv2, tfprediction_serv2, average='macro')
f1_serv2_MA
# Out:
# 0.72460038600484977

# %%
f1_serv2_WI=f1_score(y_test_serv2, tfprediction_serv2, average='weighted')
f1_serv2_WI
# Out:
# 0.76034253028326637

# %%
f1_serv2_N=f1_score(y_test_serv2, tfprediction_serv2, average=None)
f1_serv2_N
# Out:
# array([ 0.82644628,  0.62275449])

# %%
#ASPECT PRICE calculating accuracy, precision and recall for PRICE. The next similar comment will calculate for others
X_train_price2, X_test_price2, y_train_price2, y_test_price2 = train_test_split(price2_annotation_based.sentence, price2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_price2 = vect.fit_transform(X_train_price2)
test_dtm_price2 = vect.transform(X_test_price2)

# %%
train_dtm_price2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_price2 = vect.fit_transform(X_train_price2)
train_dtm_price2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_price2 = TfidfTransformer()
tr_features_all_price2 = tf_vec_all_price2.fit_transform(train_dtm_price2)
tr_features_all_price2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_price2 = vect.transform(X_test_price2)
te_features_all_price2 = tf_vec_all_price2.transform(cte_features_all_price2)
X_test_price2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_price2.shape))
# Out:
# (795, 5535)

# %%
#calculating accuracy, precision and recall for PRICE. The next similar comment will calculate for others
results_all_bi_price2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_price2 = {}
cprediction_price2 = {}
foldnum_price2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_price2, y_train_price2)
        tfprediction_price2[name] = model.predict(te_features_all_price2)
        #print(tfprediction[name])
        tfaccuracy_price2 = metrics.accuracy_score(tfprediction_price2[name],y_test_price2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_price2.loc[foldnum_price2,'TF-IDF Accuracy']=tfaccuracy_price2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_price2.loc[foldnum_price2,'Model']=name
        foldnum_price2 = foldnum_price2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_serv2)
print (results_all_bi_price2)
print (tfaccuracy_price2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.981132  BernoulliNB
# 1         0.984906     Logistic
# 2         0.977358   Perceptron
# 0.977358490566

# %%
models1_price2 = linear_model.LogisticRegression(C=1e5)
models1_price2.fit(tr_features_all_price2, y_train_price2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_price2 = models1_price2.predict(te_features_all_price2)
list(tfprediction_price2)
# Out:
# ['Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
#  'Not_Price',
# ...

# %%
from sklearn.metrics import precision_score
precision_price2_MI=precision_score(y_test_price2, tfprediction_price2, average='micro')
print(precision_price2_MI)
# Out:
# 0.984905660377

# %%
precision_price2_MA=precision_score(y_test_price2, tfprediction_price2, average='macro')
print(precision_price2_MA)
# Out:
# 0.992424242424

# %%
precision_price2_WI=precision_score(y_test_price2, tfprediction_price2, average='weighted')
print(precision_price2_WI)
# Out:
# 0.985134362493

# %%
precision_price2_N= precision_score(y_test_price2, tfprediction_price2, average=None)
precision_price2_N
# Out:
# array([ 0.98484848,  1.        ])

# %%
from sklearn.metrics import recall_score
recall_price2_MA=recall_score(y_test_price2, tfprediction_price2, average='macro')
recall_price2_MA
# Out:
# 0.59999999999999998

# %%
recall_price2_MI=recall_score(y_test_price2, tfprediction_price2, average='micro')
recall_price2_MI
# Out:
# 0.98490566037735849

# %%
recall_price2_WI=recall_score(y_test_price2, tfprediction_price2, average='weighted')
recall_price2_WI
# Out:
# 0.98490566037735849

# %%
recall_price2_N=recall_score(y_test_price2, tfprediction_price2, average=None)
recall_price2_N
# Out:
# array([ 1. ,  0.2])

# %%
from sklearn.metrics import f1_score
f1_price2_MI=f1_score(y_test_price2, tfprediction_price2, average='micro')
print(f1_price2_MI)
# Out:
# 0.984905660377

# %%
f1_price2_MA=f1_score(y_test_price2, tfprediction_price2, average='macro')
f1_price2_MA
# Out:
# 0.66284987277353691

# %%
f1_price2_WI=f1_score(y_test_price2, tfprediction_price2, average='weighted')
f1_price2_WI
# Out:
# 0.97993182581977045

# %%
f1_price2_N=f1_score(y_test_price2, tfprediction_price2, average=None)
f1_price2_N
# Out:
# array([ 0.99236641,  0.33333333])

# %%
#partitioning data for ASPECT - FOOD and calculating acc, precision, recall, f-measure
X_train_food2, X_test_food2, y_train_food2, y_test_food2 = train_test_split(food2_annotation_based.sentence, food2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_food2 = vect.fit_transform(X_train_food2)
test_dtm_food2 = vect.transform(X_test_food2)

# %%
train_dtm_food2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_food2 = vect.fit_transform(X_train_food2)
train_dtm_food2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_food2 = TfidfTransformer()
tr_features_all_food2 = tf_vec_all_food2.fit_transform(train_dtm_food2)
tr_features_all_food2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_food2 = vect.transform(X_test_food2)
te_features_all_food2 = tf_vec_all_food2.transform(cte_features_all_food2)
X_test_food2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_food2.shape))
# Out:
# (795, 5535)

# %%
results_all_bi_food2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_food2 = {}
cprediction_food2 = {}
foldnum_food2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_food2, y_train_food2)
        tfprediction_food2[name] = model.predict(te_features_all_food2)
        #print(tfprediction[name])
        tfaccuracy_food2 = metrics.accuracy_score(tfprediction_food2[name],y_test_food2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_food2.loc[foldnum_food2,'TF-IDF Accuracy']=tfaccuracy_food2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_food2.loc[foldnum_food2,'Model']=name
        foldnum_food2 = foldnum_food2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_serv2)
print (results_all_bi_food2)
print (tfaccuracy_food2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.807547  BernoulliNB
# 1         0.883019     Logistic
# 2         0.830189   Perceptron
# 0.830188679245

# %%
models1_food2 = linear_model.LogisticRegression(C=1e5)
models1_food2.fit(tr_features_all_food2, y_train_food2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_food2 = models1_food2.predict(te_features_all_food2)
list(tfprediction_food2)
# Out:
# ['Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
#  'Not_Food',
# ...

# %%
from sklearn.metrics import precision_score
precision_food2_MI=precision_score(y_test_food2, tfprediction_food2, average='micro')
print(precision_food2_MI)
# Out:
# 0.883018867925

# %%
precision_food2_MA=precision_score(y_test_food2, tfprediction_food2, average='macro')
print(precision_food2_MA)
# Out:
# 0.845110771581

# %%
precision_food2_WI=precision_score(y_test_food2, tfprediction_food2, average='weighted')
print(precision_food2_WI)
# Out:
# 0.876476353835

# %%
precision_food2_N= precision_score(y_test_food2, tfprediction_food2, average=None)
precision_food2_N
# Out:
# array([ 0.79411765,  0.8961039 ])

# %%
from sklearn.metrics import recall_score
recall_food2_MA=recall_score(y_test_food2, tfprediction_food2, average='macro')
recall_food2_MA
# Out:
# 0.74835074216602537

# %%
recall_food2_MI=recall_score(y_test_food2, tfprediction_food2, average='micro')
recall_food2_MI
# Out:
# 0.88301886792452833

# %%
recall_food2_WI=recall_score(y_test_food2, tfprediction_food2, average='weighted')
recall_food2_WI
# Out:
# 0.88301886792452833

# %%
recall_food2_N=recall_score(y_test_food2, tfprediction_food2, average=None)
recall_food2_N
# Out:
# array([ 0.52941176,  0.96728972])

# %%
from sklearn.metrics import f1_score
f1_food2_MI=f1_score(y_test_food2, tfprediction_food2, average='micro')
print(f1_food2_MI)
# Out:
# 0.883018867925

# %%
f1_food2_MA=f1_score(y_test_food2, tfprediction_food2, average='macro')
f1_food2_MA
# Out:
# 0.78281559814937218

# %%
f1_food2_WI=f1_score(y_test_food2, tfprediction_food2, average='weighted')
f1_food2_WI
# Out:
# 0.87355522577909694

# %%
f1_food2_N=f1_score(y_test_food2, tfprediction_food2, average=None)
f1_food2_N
# Out:
# array([ 0.63529412,  0.93033708])

# %%
#partitioning data for ASPECT - OTHER and calculating acc, precision, recall, f-measure
X_train_other2, X_test_other2, y_train_other2, y_test_other2 = train_test_split(other2_annotation_based.sentence, other2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_other2 = vect.fit_transform(X_train_other2)
test_dtm_other2 = vect.transform(X_test_other2)

# %%
train_dtm_other2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_other2 = vect.fit_transform(X_train_other2)
train_dtm_other2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_other2 = TfidfTransformer()
tr_features_all_other2 = tf_vec_all_other2.fit_transform(train_dtm_other2)
tr_features_all_other2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_other2 = vect.transform(X_test_other2)
te_features_all_other2 = tf_vec_all_other2.transform(cte_features_all_other2)
X_test_other2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_other2.shape))
# Out:
# (795, 5535)

# %%
results_all_bi_other2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_other2 = {}
cprediction_other2 = {}
foldnum_other2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_other2, y_train_other2)
        tfprediction_other2[name] = model.predict(te_features_all_other2)
        #print(tfprediction[name])
        tfaccuracy_other2 = metrics.accuracy_score(tfprediction_other2[name],y_test_other2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_other2.loc[foldnum_other2,'TF-IDF Accuracy']=tfaccuracy_other2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_other2.loc[foldnum_other2,'Model']=name
        foldnum_other2 = foldnum_other2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_other2)
print (results_all_bi_other2)
print (tfaccuracy_other2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.649057  BernoulliNB
# 1         0.716981     Logistic
# 2         0.683019   Perceptron
# 0.683018867925

# %%
models1_other2 = linear_model.LogisticRegression(C=1e5)
models1_other2.fit(tr_features_all_other2, y_train_other2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_other2 = models1_other2.predict(te_features_all_other2)
list(tfprediction_other2)
# Out:
# ['Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Not_Other',
#  'Other',
# ...

# %%
from sklearn.metrics import precision_score
precision_other2_MI=precision_score(y_test_other2, tfprediction_other2, average='micro')
print(precision_other2_MI)
# Out:
# 0.716981132075

# %%
precision_other2_MA=precision_score(y_test_other2, tfprediction_other2, average='macro')
print(precision_other2_MA)
# Out:
# 0.690068493151

# %%
precision_other2_WI=precision_score(y_test_other2, tfprediction_other2, average='weighted')
print(precision_other2_WI)
# Out:
# 0.707482553631

# %%
precision_other2_N= precision_score(y_test_other2, tfprediction_other2, average=None)
precision_other2_N
# Out:
# array([ 0.75      ,  0.63013699])

# %%
from sklearn.metrics import recall_score
recall_other2_MA=recall_score(y_test_other2, tfprediction_other2, average='macro')
recall_other2_MA
# Out:
# 0.6657334826427771

# %%
recall_other2_MI=recall_score(y_test_other2, tfprediction_other2, average='micro')
recall_other2_MI
# Out:
# 0.71698113207547165

# %%
recall_other2_WI=recall_score(y_test_other2, tfprediction_other2, average='weighted')
recall_other2_WI
# Out:
# 0.71698113207547165

# %%
recall_other2_N=recall_score(y_test_other2, tfprediction_other2, average=None)
recall_other2_N
# Out:
# array([ 0.84210526,  0.4893617 ])

# %%
from sklearn.metrics import f1_score
f1_other2_MI=f1_score(y_test_other2, tfprediction_other2, average='micro')
print(f1_other2_MI)
# Out:
# 0.716981132075

# %%
f1_other2_MA=f1_score(y_test_other2, tfprediction_other2, average='macro')
f1_other2_MA
# Out:
# 0.67214331667244021

# %%
f1_other2_WI=f1_score(y_test_other2, tfprediction_other2, average='weighted')
f1_other2_WI
# Out:
# 0.707373028774822

# %%
f1_other2_N=f1_score(y_test_other2, tfprediction_other2, average=None)
f1_other2_N
# Out:
# array([ 0.79338843,  0.5508982 ])

# %%
#partitioning data for ASPECT - AMBIENCE and calculating acc, precision, recall, f-measure

X_train_abm2, X_test_abm2, y_train_abm2, y_test_abm2 = train_test_split(abm2_annotation_based.sentence, abm2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_abm2 = vect.fit_transform(X_train_abm2)
test_dtm_abm2 = vect.transform(X_test_abm2)

# %%
train_dtm_abm2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_abm2 = vect.fit_transform(X_train_abm2)
train_dtm_abm2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_abm2 = TfidfTransformer()
tr_features_all_abm2 = tf_vec_all_abm2.fit_transform(train_dtm_abm2)
tr_features_all_abm2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_abm2 = vect.transform(X_test_abm2)
te_features_all_abm2 = tf_vec_all_abm2.transform(cte_features_all_abm2)
X_test_abm2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_abm2.shape))
# Out:
# (795, 5535)

# %%
#calculating accuracy, precision and recall for ambience. The next similar comment will calculate for abms
results_all_bi_abm2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_abm2 = {}
cprediction_abm2 = {}
foldnum_abm2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_abm2, y_train_abm2)
        tfprediction_abm2[name] = model.predict(te_features_all_abm2)
        #print(tfprediction[name])
        tfaccuracy_abm2 = metrics.accuracy_score(tfprediction_abm2[name],y_test_abm2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_abm2.loc[foldnum_abm2,'TF-IDF Accuracy']=tfaccuracy_abm2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_abm2.loc[foldnum_abm2,'Model']=name
        foldnum_abm2 = foldnum_abm2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_abm2)
print (results_all_bi_abm2)
print (tfaccuracy_abm2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.962264  BernoulliNB
# 1         0.969811     Logistic
# 2         0.962264   Perceptron
# 0.962264150943

# %%
models1_abm2 = linear_model.LogisticRegression(C=1e5)
models1_abm2.fit(tr_features_all_abm2, y_train_abm2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_abm2 = models1_abm2.predict(te_features_all_abm2)
list(tfprediction_abm2)
# Out:
# ['Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
#  'Not_Ambience',
# ...

# %%
from sklearn.metrics import precision_score
precision_abm2_MI=precision_score(y_test_abm2, tfprediction_abm2, average='micro')
print(precision_abm2_MI)
# Out:
# 0.969811320755

# %%
precision_abm2_MA=precision_score(y_test_abm2, tfprediction_abm2, average='macro')
print(precision_abm2_MA)
# Out:
# 0.802772373541

# %%
precision_abm2_WI=precision_score(y_test_abm2, tfprediction_abm2, average='weighted')
print(precision_abm2_WI)
# Out:
# 0.967127964173

# %%
precision_abm2_N= precision_score(y_test_abm2, tfprediction_abm2, average=None)
precision_abm2_N
# Out:
# array([ 0.625     ,  0.98054475])

# %%
from sklearn.metrics import recall_score
recall_abm2_MA=recall_score(y_test_abm2, tfprediction_abm2, average='macro')
recall_abm2_MA
# Out:
# 0.74411764705882355

# %%
recall_abm2_MI=recall_score(y_test_abm2, tfprediction_abm2, average='micro')
recall_abm2_MI
# Out:
# 0.96981132075471699

# %%
recall_abm2_WI=recall_score(y_test_abm2, tfprediction_abm2, average='weighted')
recall_abm2_WI
# Out:
# 0.96981132075471699

# %%
recall_abm2_N=recall_score(y_test_abm2, tfprediction_abm2, average=None)
recall_abm2_N
# Out:
# array([ 0.5       ,  0.98823529])

# %%
from sklearn.metrics import f1_score
f1_abm2_MI=f1_score(y_test_abm2, tfprediction_abm2, average='micro')
print(f1_abm2_MI)
# Out:
# 0.969811320755

# %%
f1_abm2_MA=f1_score(y_test_abm2, tfprediction_abm2, average='macro')
f1_abm2_MA
# Out:
# 0.76996527777777768

# %%
f1_abm2_WI=f1_score(y_test_abm2, tfprediction_abm2, average='weighted')
f1_abm2_WI
# Out:
# 0.96819313417190767

# %%
f1_abm2_N=f1_score(y_test_abm2, tfprediction_abm2, average=None)
f1_abm2_N
# Out:
# array([ 0.55555556,  0.984375  ])

# %%
#partitioning data for ASPECT - LOCATION and calculating acc, precision, recall, f-measure

X_train_loc2, X_test_loc2, y_train_loc2, y_test_loc2 = train_test_split(loc2_annotation_based.sentence, loc2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_loc2 = vect.fit_transform(X_train_loc2)
test_dtm_loc2 = vect.transform(X_test_loc2)

# %%
train_dtm_loc2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_loc2 = vect.fit_transform(X_train_loc2)
train_dtm_loc2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_loc2 = TfidfTransformer()
tr_features_all_loc2 = tf_vec_all_loc2.fit_transform(train_dtm_loc2)
tr_features_all_loc2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_loc2 = vect.transform(X_test_loc2)
te_features_all_loc2 = tf_vec_all_loc2.transform(cte_features_all_loc2)
X_test_loc2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_loc2.shape))
# Out:
# (795, 5535)

# %%
results_all_bi_loc2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_loc2 = {}
cprediction_loc2 = {}
foldnum_loc2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_loc2, y_train_loc2)
        tfprediction_loc2[name] = model.predict(te_features_all_loc2)
        #print(tfprediction[name])
        tfaccuracy_loc2 = metrics.accuracy_score(tfprediction_loc2[name],y_test_loc2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_loc2.loc[foldnum_loc2,'TF-IDF Accuracy']=tfaccuracy_loc2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_loc2.loc[foldnum_loc2,'Model']=name
        foldnum_loc2 = foldnum_loc2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_loc2)
print (results_all_bi_loc2)
print (tfaccuracy_loc2)
# Out:
#    TF-IDF Accuracy        Model
# 0         0.932075  BernoulliNB
# 1         0.950943     Logistic
# 2         0.935849   Perceptron
# 0.935849056604

# %%
models1_loc2 = linear_model.LogisticRegression(C=1e5)
models1_loc2.fit(tr_features_all_loc2, y_train_loc2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_loc2 = models1_loc2.predict(te_features_all_loc2)
list(tfprediction_loc2)
# Out:
# ['Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
#  'Not_Location',
# ...

# %%
from sklearn.metrics import precision_score
precision_loc2_MI=precision_score(y_test_loc2, tfprediction_loc2, average='micro')
print(precision_loc2_MI)
# Out:
# 0.950943396226

# %%
precision_loc2_MA=precision_score(y_test_loc2, tfprediction_loc2, average='macro')
print(precision_loc2_MA)
# Out:
# 0.975

# %%
precision_loc2_WI=precision_score(y_test_loc2, tfprediction_loc2, average='weighted')
print(precision_loc2_WI)
# Out:
# 0.953396226415

# %%
precision_loc2_N= precision_score(y_test_loc2, tfprediction_loc2, average=None)
precision_loc2_N
# Out:
# array([ 1.  ,  0.95])

# %%
from sklearn.metrics import recall_score
recall_loc2_MA=recall_score(y_test_loc2, tfprediction_loc2, average='macro')
recall_loc2_MA
# Out:
# 0.63888888888888884

# %%
recall_loc2_MI=recall_score(y_test_loc2, tfprediction_loc2, average='micro')
recall_loc2_MI
# Out:
# 0.95094339622641511

# %%
recall_loc2_WI=recall_score(y_test_loc2, tfprediction_loc2, average='weighted')
recall_loc2_WI
# Out:
# 0.95094339622641511

# %%
recall_loc2_N=recall_score(y_test_loc2, tfprediction_loc2, average=None)
recall_loc2_N
# Out:
# array([ 0.27777778,  1.        ])

# %%
from sklearn.metrics import f1_score
f1_loc2_MI=f1_score(y_test_loc2, tfprediction_loc2, average='micro')
print(f1_loc2_MI)
# Out:
# 0.950943396226

# %%
f1_loc2_MA=f1_score(y_test_loc2, tfprediction_loc2, average='macro')
f1_loc2_MA
# Out:
# 0.70457079152731328

# %%
f1_loc2_WI=f1_score(y_test_loc2, tfprediction_loc2, average='weighted')
f1_loc2_WI
# Out:
# 0.93770850423844676

# %%
f1_loc2_N=f1_score(y_test_loc2, tfprediction_loc2, average=None)
f1_loc2_N
# Out:
# array([ 0.43478261,  0.97435897])

# %%
#partitioning data for ASPECT - PARKING and calculating acc, precision, recall, f-measure

X_train_park2, X_test_park2, y_train_park2, y_test_park2 = train_test_split(park2_annotation_based.sentence, park2_annotation_based.annotation,test_size=0.25, random_state=1)
vect = CountVectorizer()
train_dtm_park2 = vect.fit_transform(X_train_park2)
test_dtm_park2 = vect.transform(X_test_park2)

# %%
train_dtm_park2.shape # rows are documents, columns are terms (aka "tokens" or "features")
# Out:
# (795, 1644)

# %%
vect = CountVectorizer(ngram_range=(1,2))
train_dtm_park2 = vect.fit_transform(X_train_park2)
train_dtm_park2.shape
# Out:
# (795, 5535)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_vec_all_park2 = TfidfTransformer()
tr_features_all_park2 = tf_vec_all_park2.fit_transform(train_dtm_park2)
tr_features_all_park2
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
cte_features_all_park2 = vect.transform(X_test_park2)
te_features_all_park2 = tf_vec_all_park2.transform(cte_features_all_park2)
X_test_park2
# Out:
# 215                                               suppose
# 663                            bacon quesarito phenomenal
# 773      really tell employees mad rude like often see...
# 798                                  wait long need smile
# 629     pretty much thing one would rate fast food joi...
# 372                                           im starving
# 537     gets annoying get subpar failquality fast food...
# 783       would recommend going one many taco bells close
# 550                        specifically one shift however
# 94      call number listed receipt complain non workin...
# 175          however quality customer service goes beyond
# 661                                  cookout got business
# 47      taco bell definitely favorite fast food locati...
# 589     mention id need 3 quesaritos fill equivalent s...
# 259              sometimes get order right sometimes dont
# 733     drive thru bit slow chicken burrito grillers q...
# ...

# %%
print ((train_dtm_park2.shape))
# Out:
# (795, 5535)

# %%
results_all_bi_park2 = pd.DataFrame()

#stratified = StratifiedKFold(labels, n_folds=5,random_state=20160121, shuffle=True)
tfprediction_park2 = {}
cprediction_park2 = {}
foldnum_park2 = 0
for name,model in models.items():
        
        model.fit(tr_features_all_park2, y_train_park2)
        tfprediction_park2[name] = model.predict(te_features_all_park2)
        #print(tfprediction[name])
        tfaccuracy_park2 = metrics.accuracy_score(tfprediction_park2[name],y_test_park2)
        
        #model.fit(ctr_features_all,Train_labels)
        #cprediction[name] = model.predict(cte_features_all)
        #caccuracy = metrics.accuracy_score(cprediction[name],Test_labels)
        
        results_all_bi_park2.loc[foldnum_park2,'TF-IDF Accuracy']=tfaccuracy_park2
        #results_all_bi.loc[foldnum,'Count Accuracy']=caccuracy
        results_all_bi_park2.loc[foldnum_park2,'Model']=name
        foldnum_park2 = foldnum_park2+1
        
        #for 'Logistic',model IN in models.items():
            #print (tfaccuracy_park2)
print (results_all_bi_park2)
print (tfaccuracy_park2)
# Out:
#    TF-IDF Accuracy        Model
# 0         1.000000  BernoulliNB
# 1         1.000000     Logistic
# 2         0.988679   Perceptron
# 0.988679245283

# %%
models1_park2 = linear_model.LogisticRegression(C=1e5)
models1_park2.fit(tr_features_all_park2, y_train_park2)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
tfprediction_park2 = models1_park2.predict(te_features_all_park2)
list(tfprediction_park2)
# Out:
# ['Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
#  'Not_Parking_availability',
# ...

# %%
from sklearn.metrics import precision_score
precision_park2_MI=precision_score(y_test_park2, tfprediction_park2, average='micro')
print(precision_park2_MI)
# Out:
# 1.0

# %%
precision_park2_MA=precision_score(y_test_park2, tfprediction_park2, average='macro')
print(precision_park2_MA)
# Out:
# 1.0

# %%
precision_park2_WI=precision_score(y_test_park2, tfprediction_park2, average='weighted')
print(precision_park2_WI)
# Out:
# 1.0

# %%
precision_park2_N= precision_score(y_test_park2, tfprediction_park2, average=None)
precision_park2_N
# Out:
# array([ 1.])

# %%
from sklearn.metrics import recall_score
recall_park2_MA=recall_score(y_test_park2, tfprediction_park2, average='macro')
recall_park2_MA
# Out:
# 1.0

# %%
recall_park2_MI=recall_score(y_test_park2, tfprediction_park2, average='micro')
recall_park2_MI
# Out:
# 1.0

# %%
recall_park2_WI=recall_score(y_test_park2, tfprediction_park2, average='weighted')
recall_park2_WI
# Out:
# 1.0

# %%
recall_park2_N=recall_score(y_test_park2, tfprediction_park2, average=None)
recall_park2_N
# Out:
# array([ 1.])

# %%
from sklearn.metrics import f1_score
f1_park2_MI=f1_score(y_test_park2, tfprediction_park2, average='micro')
print(f1_park2_MI)
# Out:
# 1.0

# %%
f1_park2_MA=f1_score(y_test_park2, tfprediction_park2, average='macro')
f1_park2_MA
# Out:
# 1.0

# %%
f1_park2_WI=f1_score(y_test_park2, tfprediction_park2, average='weighted')
f1_park2_WI
# Out:
# 1.0

# %%
f1_park2_N=f1_score(y_test_park2, tfprediction_park2, average=None)
f1_park2_N
# Out:
# array([ 1.])

# %%
#the average precision of all aspects
avg_precision_MI = (precision_serv2_MI + precision_price2_MI + precision_food2_MI + precision_other2_MI + precision_abm2_MI + precision_loc2_MI + precision_park2_MI)/7
avg_precision_MI
# Out:
# 0.89541778975741237

# %%
avg_recall_MI = (recall_serv2_MI + recall_price2_MI + recall_food2_MI + recall_other2_MI + recall_abm2_MI + recall_loc2_MI + recall_park2_MI)/7
avg_recall_MI
# Out:
# 0.89541778975741237

# %%
avg_fmeasure_MI = (f1_serv2_MI + f1_price2_MI + f1_food2_MI + f1_other2_MI + f1_abm2_MI + f1_loc2_MI + f1_park2_MI)/7
avg_fmeasure_MI
# Out:
# 0.89541778975741237

# %%
#No changes after this comment

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import pylab as pl
area = auc(recall, precision)
print("Area Under Curve: %0.2f" % area)
pl.clf()
pl.plot(recall, precision, label='Precision-Recall curve')
pl.xlabel('Recall')
pl.ylabel('Precision')
pl.ylim([0.0, 1.05])
pl.xlim([0.0, 1.0])
pl.title('Precision-Recall example: AUC=%0.2f' % area)
pl.legend(loc="lower left")
pl.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-518-bd3d898caf08> in <module>()
#       2 from sklearn.metrics import auc
#       3 import pylab as pl
# ----> 4 area = auc(recall, precision)
#       5 print("Area Under Curve: %0.2f" % area)
#       6 pl.clf()
#
# C:\Users\Rency\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in auc(x, y, reorder)
#      78
#      79     """
# ---> 80     check_consistent_length(x, y)
#      81     x = column_or_1d(x)
#      82     y = column_or_1d(y)
#
# C:\Users\Rency\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     175     """
#     176
# --> 177     lengths = [_num_samples(X) for X in arrays if X is not None]
#     178     uniques = np.unique(lengths)
#     179     if len(uniques) > 1:
#
# ...

# %%
percentile_list = pd.DataFrame({'Prediction': list(tfprediction),'sentence': list(X_test),'Actual':list(y_test)})
percentile_list
# Out:
#        Actual Prediction                                           sentence
# 0    Not_Food   Not_Food                                            suppose
# 1        Food   Not_Food                         bacon quesarito phenomenal
# 2        Food       Food   really tell employees mad rude like often see...
# 3    Not_Food       Food                               wait long need smile
# 4    Not_Food       Food  pretty much thing one would rate fast food joi...
# 5        Food   Not_Food                                        im starving
# 6    Not_Food       Food  gets annoying get subpar failquality fast food...
# 7    Not_Food   Not_Food    would recommend going one many taco bells close
# 8    Not_Food       Food                     specifically one shift however
# 9    Not_Food       Food  call number listed receipt complain non workin...
# 10       Food       Food       however quality customer service goes beyond
# ...

# %%
train_dtm = vect.fit_transform(X_train)
test_dtm = vect.transform(X_test)

# %%
nb = MultinomialNB()
nb.fit(train_dtm, y_train)
y_pred_class = nb.predict(test_dtm)

# %%
train_dtm
# Out:
# <795x5535 sparse matrix of type '<class 'numpy.int64'>'
# 	with 9597 stored elements in Compressed Sparse Row format>

# %%
test_dtm
# Out:
# <265x5535 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1712 stored elements in Compressed Sparse Row format>

# %%
y_pred_class
# Out:
# array(['Food', 'Food', 'Food', 'Food', 'Food', 'Not_Food', 'Food',
#        'Not_Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food',
#        'Food', 'Not_Food', 'Food', 'Not_Food', 'Not_Food', 'Not_Food',
#        'Not_Food', 'Not_Food', 'Not_Food', 'Food', 'Food', 'Not_Food',
#        'Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food',
#        'Not_Food', 'Food', 'Not_Food', 'Not_Food', 'Not_Food', 'Food',
#        'Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food', 'Food',
#        'Food', 'Not_Food', 'Food', 'Not_Food', 'Not_Food', 'Food',
#        'Not_Food', 'Food', 'Food', 'Not_Food', 'Food', 'Food', 'Food',
#        'Food', 'Not_Food', 'Food', 'Not_Food', 'Not_Food', 'Not_Food',
#        'Food', 'Food', 'Food', 'Food', 'Not_Food', 'Not_Food', 'Not_Food',
#        'Food', 'Food', 'Not_Food', 'Food', 'Food', 'Food', 'Food',
#        'Not_Food', 'Not_Food', 'Not_Food', 'Food', 'Food', 'Not_Food',
# ...

# %%
print(metrics.accuracy_score(y_test, y_pred_class))
# Out:
# 0.671698113208
